# %%
import numpy as np

# %%
def LinearRegression(x,y):
    x_m = np.mean(x)
    y_m = np.mean(y)
    num = 0
    den = 0
    
    n=len(x)
    for i in range(n):
        num = num + (x[i] - x_m) * (y[i]-y_m)
        den = den + (x[i] - x_m)**2
    
    m=num/den
    c=y_m -m * x_m
    return m,c
    
    
x=[1,2,3,4,5]
y=[3,4,2,4,5]

# %%
m,c = LinearRegression(x,y)
print(f"y = {m}x + {c}")
# Out:
# y = 0.4x + 2.4

# %%
def Predict(x):
    y_p = []
    for i in range(len(x)):
        y_p.append(m * x[i] + c)
    return y_p

y_p = Predict(x)
print(y_p)
# Out:
# [2.8, 3.2, 3.6, 4.0, 4.4]

# %%
y_m = np.mean(y)
r2 = 1 - ((sum(y_p - y_m) ** 2) / (sum(y - y_m) ** 2))
print(f"r2 = {r2}")
# Out:
# r2 = 1.0

# %%
y, y_p
# Out:
# ([3, 4, 2, 4, 5], [2.8, 3.2, 3.6, 4.0, 4.4])

# %%
def r2_score(y,y_p):
    y_m = np.mean(y)
    print(f"Mean of y : {y_m}")
    num = 0
    den = 0
    
    for i in range(len(y)):
        num = num + ((y_p - y_m) ** 2)
        den = den + ((y - y_m) ** 2)
    return num/den

# %%
print("r2 score : ",r2_score(y,y_p))
# Out:
# Mean of y : 3.6
# r2 score :  [1.77777778 1.         0.         1.         0.32653061]

# %%
print("Accuracy : ",1-r2_score(y,y_p))
# Out:
# Mean of y : 3.6
# Accuracy :  [-0.77777778  0.          1.          0.          0.67346939]

# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/CVR/Downloads/headbrain.csv')
df
# Out:
#      Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0         1          1             4512                 1530
# 1         1          1             3738                 1297
# 2         1          1             4261                 1335
# 3         1          1             3777                 1282
# 4         1          1             4177                 1590
# ..      ...        ...              ...                  ...
# 232       2          2             3214                 1110
# 233       2          2             3394                 1215
# 234       2          2             3233                 1104
# 235       2          2             3352                 1170
# 236       2          2             3391                 1120
#
# [237 rows x 4 columns]

# %%
def Linear_Regression_HeadBrain(x,y):
    x_m = np.mean(x)
    y_m = np.mean(y)
    num = 0
    den = 0
    
    n=len(x)
    for i in range(n):
        num = num + (x[i] - x_m) * (y[i]-y_m)
        den = den + (x[i] - x_m)**2
    
    m=num/den
    c=y_m -m * x_m
    return m,c
    
    
x=df['Head Size(cm^3)']
y=df['Brain Weight(grams)']

# %%
m,c = Linear_Regression_HeadBrain(x,y)
print(f"y = {m}x + {c}")
# Out:
# y = 0.26342933948939945x + 325.57342104944223

# %%
def Predict_HeadBrain(x):
    y_p = []
    for i in range(len(x)):
        y_p.append(m * x[i] + c)
    return y_p

y_p = Predict_HeadBrain(x)
print(y_p)
# Out:
# [1514.1666008256125, 1310.2722920608173, 1448.0458366137732, 1320.546036300904, 1425.9177720966638, 1269.9676031189392, 1322.6534710168191, 1263.118440292215, 1277.3436246246424, 1374.549050896231, 1232.5606369114446, 1377.4467736306142, 1284.4562167908562, 1434.0840816208351, 1335.034649972821, 1346.6255409103546, 1246.785821243872, 1238.6195117197008, 1140.8872267691336, 1490.9848189505453, 1347.1523995893333, 1391.4085286235525, 1327.6586284671178, 1302.8962705551141, 1576.0724956056215, 1490.721389611056, 1388.7742352286584, 1385.0862244758068, 1235.4583596458278, 1425.390913417685, 1323.1803296957978, 1325.5511937512024, 1406.424000974448, 1421.7029026648333, 1420.9126146463652, 1330.2929218620118, 1254.688701428554, 1312.9065854557114, 1203.8468389071, 1245.468674546425, 1369.2804641064429, 1248.8932559597874, 1462.271020946201, 1327.6586284671178, 1343.2009594969923, 1388.2473765496795, 1460.427015569775, 1159.3272805333913, 1284.7196461303456, 1285.509934148814, 1350.57698100
# ...

# %%
y_m = np.mean(y)
r2 = 1 - ((sum(y_p - y_m) ** 2) / (sum(y - y_m) ** 2))
print(f"r2 = {r2}")
# Out:
# r2 = 0.8019517008853924

# %%
y, y_p
# Out:
# (0      1530
#  1      1297
#  2      1335
#  3      1282
#  4      1590
#         ...
#  232    1110
#  233    1215
#  234    1104
#  235    1170
#  236    1120
#  Name: Brain Weight(grams), Length: 237, dtype: int64,
#  [1514.1666008256125,
#   1310.2722920608173,
#   1448.0458366137732,
#   1320.546036300904,
#   1425.9177720966638,
#   1269.9676031189392,
#   1322.6534710168191,
#   1263.118440292215,
#   1277.3436246246424,
#   1374.549050896231,
#   1232.5606369114446,
#   1377.4467736306142,
#   1284.4562167908562,
#   1434.0840816208351,
#   1335.034649972821,
#   1346.6255409103546,
#   1246.785821243872,
#   1238.6195117197008,
#   1140.8872267691336,
#   1490.9848189505453,
#   1347.1523995893333,
#   1391.4085286235525,
#   1327.6586284671178,
#   1302.8962705551141,
#   1576.0724956056215,
#   1490.721389611056,
#   1388.7742352286584,
#   1385.0862244758068,
#   1235.4583596458278,
#   1425.390913417685,
#   1323.1803296957978,
#   1325.5511937512024,
# ...

# %%
def r2_score(y,y_p):
    y_m = np.mean(y)
    print(f"Mean of y : {y_m}")
    num = 0
    den = 0
    
    for i in range(len(y)):
        num = num + ((y_p - y_m) ** 2)
        den = den + ((y - y_m) ** 2)
    return num/den

# %%
print("r2 score : ",r2_score(y,y_p))
# Out:
# Mean of y : 1282.873417721519
# r2 score :  0         0.875965
# 1         3.761761
# 2        10.040528
# 3      1860.405515
# 4         0.216924
#           ...
# 232       0.409593
# 233       0.867602
# 234       0.348744
# 235       0.433129
# 236       0.154458
# Name: Brain Weight(grams), Length: 237, dtype: float64

# %%
print("Accuracy : ",1-r2_score(y,y_p))
# Out:
# Mean of y : 1282.873417721519
# Accuracy :  0         0.124035
# 1        -2.761761
# 2        -9.040528
# 3     -1859.405515
# 4         0.783076
#           ...
# 232       0.590407
# 233       0.132398
# 234       0.651256
# 235       0.566871
# 236       0.845542
# Name: Brain Weight(grams), Length: 237, dtype: float64
